# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
#org = pd.DataFrame.from_csv('organizations.csv', index_col=None).fillna('')
org['name_lower'] = org['name'].str.lower().str.replace(' ','')
org.head()
# Out:
#                         crunchbase_uuid          type primary_role  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Organization      company
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7  Organization      company
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0  Organization      company
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Organization     investor
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb  Organization      company
#
#               name                                     crunchbase_url  \
# 0         Wetpaint  https://www.crunchbase.com/organization/wetpai...
# 1             Zoho  https://www.crunchbase.com/organization/zoho?u...
# 2             Digg  https://www.crunchbase.com/organization/digg?u...
# 3  Omidyar Network  https://www.crunchbase.com/organization/omidya...
# 4         Facebook  https://www.crunchbase.com/organization/facebo...
#
#     homepage_domain             homepage_url  \
# 0  wetpaint-inc.com  http://wetpaint-inc.com
# 1          zoho.com    https://www.zoho.com/
# ...

# %%
shark = pd.DataFrame.from_csv('SharkTankData.csv',index_col = None).fillna('')
shark['company_lower'] = shark['Company'].str.lower().str.replace(' ','')
shark.head()
# Out:
#   Season No. in series                Company Deal           Industry  \
# 0
# 1
# 2      1             1       Ava the Elephant  Yes         Healthcare
# 3      1             1  Mr. Tod's Pie Factory  Yes  Food and Beverage
# 4      1             1                Wispots   No  Business Services
#
#   Entrepreneur Gender     ASK Unnamed: 7 Unnamed: 8       DEAL  \
# 0                      Amount     Equity  Valuation     Amount
# 1
# 2              Female                                 $50,000
# 3                Male                                $460,000
# 4                Male
#
#           ...         # Sharks $ per shark Details / Notes Description url1  \
# 0         ...
# 1         ...
# 2         ...                1    $50,000
# 3         ...                2   $230,000
# 4         ...                0
#
#   url2 url3 url4 url5       company_lower
# 0
# 1
# 2                          avatheelephant
# 3                      mr.tod'spiefactory
# ...

# %%
result = pd.merge(org, shark[shark.Company != np.NaN], how='inner', left_on ='name_lower', right_on ='company_lower')
result
# Out:
#                           crunchbase_uuid          type primary_role  \
# 0    880e1e33-bafc-9797-e903-97baf1d09554  Organization      company
# 1    a5c7d8a0-18d8-2abd-5a3e-3cbf50592344  Organization      company
# 2    e2b7bfca-4878-af0a-eedc-224a41f62078  Organization      company
# 3    39896760-f72f-3008-9ebd-54db782e591e  Organization      company
# 4    429a0da2-15c8-b201-a939-0657b62a3f01  Organization      company
# 5    3a5bf632-fb3c-97ce-7863-b1d4f60781cd  Organization      company
# 6    d4d20f7f-f839-cb37-058b-f547193efe2b  Organization      company
# 7    80df2107-435a-0435-f065-8cac8f7aa669  Organization      company
# 8    1eaf7803-9ef9-d8b0-3995-3976fe45fdfe  Organization      company
# 9    0f8d6203-020a-4d09-c28e-f087fc48a3c2  Organization      company
# 10   5f2b01bd-dd5d-1c49-c432-8c70205d44bf  Organization      company
# 11   4118cfb5-b6da-fc6b-3bd3-86db079eebb7  Organization      company
# 12   ec77d032-682d-629d-d5a1-aa36f0fe5513  Organization      company
# ...

# %%
import urllib
import json as m_json
query = raw_input ( 'Query: ' )
query = urllib.urlencode ( { 'q' : query } )
print 'http://ajax.googleapis.com/ajax/services/search/web?v=1.0&' + query 
response = urllib.urlopen ( 'http://ajax.googleapis.com/ajax/services/search/web?v=1.0&' + query ).read()
json = m_json.loads ( response )
results = json [ 'responseData' ] [ 'results' ]
for result in results:
    title = result['title']
    url = result['url']   # was URL in the original and that threw a name error exception
    print ( title + '; ' + url )
# Out:
# Query: Ava the Elephant
# http://ajax.googleapis.com/ajax/services/search/web?v=1.0&q=Ava+the+Elephant
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-93c094b9d92f> in <module>()
#       6 response = urllib.urlopen ( 'http://ajax.googleapis.com/ajax/services/search/web?v=1.0&' + query ).read()
#       7 json = m_json.loads ( response )
# ----> 8 results = json [ 'responseData' ] [ 'results' ]
#       9 for result in results:
#      10     title = result['title']
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %%
import pandas as pd
from py_bing_search import PyBingSearch
bing = PyBingSearch('paSGB6b2usCi0JLD3m/osqTRssw+aBz39iAQx0Dllt0')

new_shark = pd.DataFrame.copy(shark)
#new_shark.add(['description','url1','url2','url3','url4','url5'],axis='columns')
for index, row in shark.iterrows():
    if index > 1:
        company = row.Company
        result_list, next_uri = bing.search(company + ' facebook', limit=5,format='json')
        row1 = row
        row.Description = result_list[0].description.encode(encoding='UTF-8')
        row.url1 = result_list[0].url.encode(encoding='UTF-8')
        row.url2 = result_list[1].url.encode(encoding='UTF-8')
        row.url3 = result_list[2].url.encode(encoding='UTF-8')
        row.url4 = result_list[3].url.encode(encoding='UTF-8')
        row.url5 = result_list[4].url.encode(encoding='UTF-8')
        
shark.to_csv('SharkTankData_updated_4.csv',index_col = None)

#result_list, next_uri = bing.search("Python Software Foundation", limit=5,format='json')

# %%
shark.to_csv('SharkTankData_updated_2_1.csv',index_col = None)

# %%
import awis
api = awis.AwisApi("AKIAJJERMCBITZZ4CBVA", "7x1iauCYWHithMDqgR9uxWnoMkWSWyRAGoeDIf+8")
tree = api.url_info("http://www.google.com/", "Rank", "LinksInCount","SiteData","UsageStats","Categories")
elem = tree.find("//{%s}StatusCode" % api.NS_PREFIXES["alexa"])
assert elem.text == "Success"
tree.write('test.xml')
